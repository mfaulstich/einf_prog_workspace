# %%
alter = 21 
if [alter >= 18]:
    print("Sie sind volljährig!")
# Out:
# Sie sind volljährig!

# %%
FileNotFoundError
PermissionError
IsADirectoryError
IOError
EOFError
OSError
ValueError


DiskFullError
FileEmptyError
DiskNotFoundErrorr
VirusFoundError
FileCorruptError
DiskEjectError
StickDefectError
# Out:
# else-Block ausgeführt
