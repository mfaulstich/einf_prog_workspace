# %%
#
# Harmonische Reihe
# 

#####################################################
# Lösung Studierende
#####################################################

# BEGIN Vorbelegung des Antwortfeldes
def harmonic_series(n:int):
    # Ihr Code hier
# END Vorbelegung des Antwortfeldes
    if n < 1:
        raise ValueError(f"Erwarte positiven Wert für n, ist aber {n}")
    result = 0.0
    for i in range(n):
        result += 1.0/(i+1)
    return result

# %%
#####################################################
# Testfall 1: Fehlerbehandlung
# Der Code in der Methode ist der Coderunner-Testfall
#####################################################
# Erwartete Ausgabe: VALUEERROR
#####################################################

# BEGIN Testfall 1
try:
    harmonic_series(0)
    print("NO ERROR", end="")
except ValueError:
    print("VALUEERROR", end="")
# END Testfall 1
# Out:
# VALUEERROR

# %%
#####################################################
# Testfall 2: Fehlerbehandlung
# Der Code in der Methode ist der Coderunner-Testfall
#####################################################
# Erwartete Ausgabe: VALUEERROR
#####################################################

# BEGIN Testfall 2
try:
    harmonic_series(-1)
    print("NO ERROR", end="")
except ValueError:
    print("VALUEERROR", end="")
# END Testfall 2
# Out:
# VALUEERROR

# %%
#####################################################
# Testfall 3: Fehlerbehandlung
# Der Code in der Methode ist der Coderunner-Testfall
#####################################################
# Erwartete Ausgabe: VALUEERROR
#####################################################

# BEGIN Testfall 3
import sys
try:
    harmonic_series(-(sys.maxsize-1))
    print("NO ERROR", end="")
except ValueError:
    print("VALUEERROR", end="")
# END Testfall 3
# Out:
# VALUEERROR

# %%
#####################################################
# Testfall 4: Funktion
# Der Code in der Methode ist der Coderunner-Testfall
#####################################################
# Erwartete Ausgabe: OK
#####################################################
# BEGIN Testfall 4
import math

def __hsr(n:int):
    if n < 1:
        raise ValueError(f"Erwarte positiven Wert für n, ist aber {n}")
    result = 0.0
    for i in range(n):
        result += 1.0/(i+1)
    return result


def __xhr():
    n=20000
    for n in range(1, 20000,100):
     rs = None
     fr=__hsr(n) - harmonic_series(n)
     if (math.fabs(fr) > 1E-10 ):
            rs = (n, fr)
            break;
    if (rs is not None):
        print(f"NOT OK n={rs[0]}: {rs[1]}", end="")
    else:
        print("OK", end="")

# Auskommentieren für Testfall        
#__xhr()       

# END Testfall 4
    
# Simulation Auswertung von Moodle-Coderunner-Testfall
import io
from contextlib import redirect_stdout
    
# Buffer für STDOUT
buffer = io.StringIO()
# STDOUT umleiten
with redirect_stdout(buffer):
   __xhr()
        
# Ausgabe abrufen
output = buffer.getvalue()
print(output)
assert "OK" == output
# Out:
# OK

# %% [markdown]
# ChatGPT Vorschlag
# Der hier gezeigte Testcode wird im Gegensatz zu den
#
# # 1. Testfall nicht anzeigen: Template-Grader verwenden
#
# Wenn du Testcode nicht anzeigen willst, musst du den Testfall in den Template-Code verlegen, nicht in die expliziten „Testcases“.
# Damit wird im Fehlerfall kein einzelner Test angezeigt, sondern nur die Gesamtausgabe deines grading-Scripts.
#
# 1. Fragetyp:<br>
# ➤ „Python3: TemplateGrader“ oder „Custom grading“ verwenden.
# 2. In den normalen Testfällen nur einen einzigen Dummy-Test lassen (oder gar keinen, je nach Fragetyp).
# 3. Den kompletten Testcode in den Grading-Template verschieben:
#
# ```
# # Der gesamte Lösungscode des Studenten ist hier bereits eingebettet ({{ STUDENT_ANSWER }})
# import sys
# import json
#
# def run_tests():
#     results = []
#
#     # Beispieltest, dessen Code nicht angezeigt wird
#     try:
#         out = some_function(5)
#         if out == 42:
#             results.append({"test": "T1", "result": True})
#         else:
#             results.append({"test": "T1", "result": False, "msg": f"Expected 42, got {out}"})
#     except Exception as e:
#         results.append({"test": "T1", "result": False, "msg": str(e)})
#
#     return results
#
# print(json.dumps(run_tests()))
#
# ```

# %% [markdown]
# So erreichst du trotzdem dein Ziel<br>
# (Testfall mit Lösungscode zum Wertevergleich verbergen, andere Testfälle als Hinweis anzeigen lassen.)
#
# 👉 Lösung: Alle Tests in den Template-Grader verlagern
#
# Du lässt die formerly „normalen“ Tests weiterhin sichtbar erscheinen, aber ihre Bewertung läuft über das JSON-Ergebnis des Template-Graders.
#
# So kannst du:
#
# ✔ jeden Test einzeln bewerten
# ✔ Punkte pro Test vergeben
# ✔ sichtbare Tests zeigen
# ✔ einen geheimen/komplexen Test enthalten
# ✔ alles zu einer Gesamtpunktzahl addieren
# ✔️ Beispiel: Template-Grader mit gemischten Tests
#
# Angenommen:
#
#     Sichtbare Tests: 3 Tests à 2 Punkte
#
#     Geheimer Test im Template-Grader: 4 Punkte
#
# Grading-Template (Python)
#
# ```
# # STUDENT_ANSWER ist eingebettet
# {{ STUDENT_ANSWER }}
#
# import json
#
# results = []
#
# total_score = 0
# max_score = 0
#
# # --- Sichtbare Tests (entsprechen normalen Testcases) ---
# # Test 1
# max_score += 2
# try:
#     ok = (myfunc(1) == 2)
#     if ok:
#         total_score += 2
#     results.append({"name": "Test 1", "passed": ok})
# except Exception as e:
#     results.append({"name": "Test 1", "passed": False, "error": str(e)})
#
# # Test 2
# max_score += 2
# try:
#     ok = (myfunc(2) == 4)
#     if ok:
#         total_score += 2
#     results.append({"name": "Test 2", "passed": ok})
# except Exception as e:
#     results.append({"name": "Test 2", "passed": False, "error": str(e)})
#
# # Test 3
# max_score += 2
# try:
#     ok = (myfunc(3) == 6)
#     if ok:
#         total_score += 2
#     results.append({"name": "Test 3", "passed": ok})
# except Exception as e:
#     results.append({"name": "Test 3", "passed": False, "error": str(e)})
#
# # --- Geheimer Test ---
# max_score += 4
# try:
#     ok = (myfunc(10) == 20)
#     if ok:
#         total_score += 4
#     results.append({"name": "Secret Test", "passed": ok})
# except Exception as e:
#     results.append({"name": "Secret Test", "passed": False, "error": str(e)})
#
# # Gesamtergebnis zurückgeben
# print(json.dumps({
#     "testresults": results,
#     "score": total_score / max_score   # CodeRunner erwartet einen Wert 0..1
# }))
#
# ```

# %% [markdown]
# # GANZ Wichtig
#
# * Testfälle im Custom-Grader werden nicht im Test angezeigt.
# * Wenn ein Custom-Grader verwendet wird, muss dieser die Komplett-Bewertung übernehmen.
# * Wenn Testfälle angezeigt werden sollen, müssen sie mit dem Testfall-Editor zur Anzeige angelegt und zusätzlich im Custom-Grader zur Bewertung implementiert werden.
#
# ChatGPT:
#
# ✔️ Grundregel (zentral wichtig)
#
# Sobald du einen Custom Template-Grader verwendest, ignoriert CodeRunner automatisch die normale Testfall-Bewertung.
#
# ➡️ Die im Editor angelegten Tests werden ausgeführt, aber nicht bewertet.
# ➡️ Nur der Custom-Grader bestimmt die Punkte.
#
# Daraus folgt:
# Wenn du die sichtbaren Tests mitbewerten willst, musst du sie im Custom-Grader selbst erneut auswerten.
#
# Das macht man normalerweise so:
#
#     Testcases im Editor anlegen → damit sie für die Studierenden sichtbar sind.
#
#     Im Custom-Grader die gleichen Tests erneut programmatisch ausführen → für die Punkte.
#
# Damit sind sie:
#
#     sichtbar, weil sie im Editor stehen,
#
#     bewertet, weil dein Grader sie berücksichtigt,
#
#     aber ohne Anzeige des Testcodes, weil die Bewertung durch dein Template-Grader erfolgt.
